# %% [markdown]
# Let's begin with the standard imports!

# %%
import numpy as np       # For the math
import seaborn as sns    # To help your vision (I meant visualization)
from matplotlib import pyplot as plt    # visualization

# %% [markdown]
# We'll now create some random data to test our implement dimensionality reduction on. Let's try to visulaize it on a 2D dataset as below.

# %%
random = np.random.RandomState(10)
X = np.dot(random.rand(2, 2), random.randn(2, 500)).T
plt.scatter(X[:, 0], X[:, 1])
plt.axis('equal');

# %%
random
# Out:
# array([[-1.17287995e+00, -2.89351851e-01],
#        [-1.83551631e-02, -4.34292588e-01],
#        [ 5.05709017e-01,  1.34847016e+00],
#        [-5.62240764e-01, -7.02511653e-01],
#        [ 2.01757710e-01,  5.86603843e-02],
#        [ 1.05690342e-01,  8.61343049e-01],
#        [ 1.00493355e-03, -8.04582091e-02],
#        [-1.35479606e-01, -1.39749459e-01],
#        [ 3.27312369e-01,  3.29992464e-02],
#        [ 9.14111624e-01,  2.63774544e-01],
#        [-7.58997312e-01, -1.13913435e+00],
#        [ 7.85787757e-01,  3.86665148e-01],
#        [ 1.79499929e-01,  2.58634921e-01],
#        [ 3.37031083e-01,  5.42743942e-02],
#        [-9.01148275e-01, -1.60293671e+00],
#        [ 1.01139070e-01, -2.60419052e-02],
#        [ 1.14038284e+00,  7.72120855e-01],
#        [-8.31419959e-01, -6.31684592e-01],
#        [-1.51608137e+00, -9.14674338e-01],
#        [-1.33859653e+00, -8.84484576e-01],
#        [ 1.88052964e-01, -4.51047821e-01],
#        [ 1.82238214e+00,  8.90867876e-01],
# ...
